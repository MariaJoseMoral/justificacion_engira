# %%
from pathlib import Path

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

ROOT = Path.cwd()
if not (ROOT / 'outputs').exists():
    ROOT = ROOT.parent

FACTURAS = ROOT / 'outputs' / '03_economica' / 'relacion_facturas_gastos.csv'
assert FACTURAS.is_file(), f'No se encuentra el documento: {FACTURAS}'
facturas = pd.read_csv(FACTURAS, dtype='string', keep_default_na=False)
facturas.head(10)
