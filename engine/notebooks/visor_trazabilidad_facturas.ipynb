# %%
from pathlib import Path

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

ROOT = Path.cwd()
if not (ROOT / 'outputs').exists():
    ROOT = ROOT.parent

TRAZABILIDAD = ROOT / 'outputs' / '03_economica' / 'relacion_facturas_gastos_trazabilidad.csv'
assert TRAZABILIDAD.is_file(), f'No se encuentra el documento: {TRAZABILIDAD}'
trazabilidad = pd.read_csv(TRAZABILIDAD, dtype='string', keep_default_na=False)
trazabilidad.head(10)
