# %%
from pathlib import Path

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

ROOT = Path.cwd()
if not (ROOT / 'outputs').exists():
    ROOT = ROOT.parent

REVISION = ROOT / 'outputs' / '03_economica' / 'revision_extraccion_facturas.csv'
assert REVISION.is_file(), f'No se encuentra el documento: {REVISION}'
revision = pd.read_csv(REVISION, dtype='string', keep_default_na=False)
revision.head(10)

# %%
revision.info()
